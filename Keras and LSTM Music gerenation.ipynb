# %% [markdown]
# # Mount Google drive
# Note: before running any cell, please check that your Runtime has GPU!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Clone codes form github

# %%
# !git clone https://github.com/subpath/Keras_music_gereration
# Out:
# Cloning into 'Keras_music_gereration'...
# remote: Enumerating objects: 100, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 100 (delta 0), reused 10 (delta 0), pack-reused 90
# Receiving objects: 100% (100/100), 52.94 MiB | 33.24 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %% [markdown]
# # install the libraries
# Here you can see which libraries with which version is used

# %%
# !pip install tensorflow==1.14.0
# !pip install tensorflow-gpu==1.14.0
# !pip install mido==1.2.9
# !pip install Keras==2.1.2
# !pip install sklearn==0.0
# !pip install numpy==1.17.3
# Out:
# Collecting tensorflow==1.14.0
#   Downloading tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3 MB)
#      |████████████████████████████████| 109.3 MB 65 kB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (3.17.3)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (0.2.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (0.5.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (1.14.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 45.1 MB/s
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488 kB)
#      |████████████████████████████████| 488 kB 2.0 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (1.46.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (1.21.6)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.1 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (0.37.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (1.0.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (1.1.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14.0) (3.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.3.7)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow==1.14.0) (1.5.2)
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0+zzzcolab20220506162203
#     Uninstalling tensorflow-2.8.0+zzzcolab20220506162203:
#       Successfully uninstalled tensorflow-2.8.0+zzzcolab20220506162203
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.14.0 which is incompatible.
# Successfully installed keras-applications-1.0.8 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0
# Collecting tensorflow-gpu==1.14.0
#   Downloading tensorflow_gpu-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (377.1 MB)
#      |████████████████████████████████| 377.1 MB 9.3 kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.46.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.21.6)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.1.2)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.5.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.0.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.37.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (0.2.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.14.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu==1.14.0) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (4.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (1.5.2)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.14.0
# Collecting mido==1.2.9
#   Downloading mido-1.2.9-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Installing collected packages: mido
# Successfully installed mido-1.2.9
# Collecting Keras==2.1.2
#   Downloading Keras-2.1.2-py2.py3-none-any.whl (304 kB)
#      |████████████████████████████████| 304 kB 8.7 MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras==2.1.2) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from Keras==2.1.2) (1.21.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from Keras==2.1.2) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras==2.1.2) (3.13)
# Installing collected packages: Keras
#   Attempting uninstall: Keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
# Successfully installed Keras-2.1.2
# Requirement already satisfied: sklearn==0.0 in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn==0.0) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn==0.0) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn==0.0) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn==0.0) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn==0.0) (1.1.0)
# Collecting numpy==1.17.3
#   Downloading numpy-1.17.3-cp37-cp37m-manylinux1_x86_64.whl (20.0 MB)
#      |████████████████████████████████| 20.0 MB 25 kB/s
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 0.20.2 requires numpy>=1.18, but you have numpy 1.17.3 which is incompatible.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.17.3 which is incompatible.
# tables 3.7.0 requires numpy>=1.19.0, but you have numpy 1.17.3 which is incompatible.
# kapre 0.3.7 requires numpy>=1.18.5, but you have numpy 1.17.3 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.14.0 which is incompatible.
# jaxlib 0.3.7+cuda11.cudnn805 requires numpy>=1.19, but you have numpy 1.17.3 which is incompatible.
# jax 0.3.8 requires numpy>=1.19, but you have numpy 1.17.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.17.3

# %% [markdown]
# # Music gereration firth Keras and TensorFlow backend
#
# Plan was simple:
# 1. Read midi file, convert it to matrix of features
# 2. Create simple model with Keras and LSTM to learn the pattern
# 3. Use subsample of initial midi file as a input for model to generate pure art
# 4. Save prediction from model to midi file
# .
# .
# .
# 5. PROFIT

# %%
import sys

#!{sys.executable} -m pip install -q mido tqdm pandas tensorflow scikit-learn
# on my macOS I couldn't import keras properly, so I reinstall it with this command
# maybe you will need it too 🤷‍♂️
# !{sys.executable} -m  pip uninstall -y tensorflow keras tf-nightly keras-nightly

# %%
import mido
import numpy as np
from mido import Message, MidiFile, MidiTrack
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import sequence
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ##### Read midi file
# You can choose another music to generate another song based on that

# %%
mid = MidiFile(
    "/content/Keras_music_gereration/Samples/Nintendo_-_Pokemon_Fire_Red_Route_1_Piano_Cover_Hard_Version.mid"
)
notes = []

# %% [markdown]
# ##### Extract notes sequence
# for the sake of simplicity I will use only 1 channel, it's like playining on piano with 1 hand 🙃

# %%
notes = []
for msg in mid:
    if not msg.is_meta and msg.channel == 0 and msg.type == "note_on":
        data = msg.bytes()
        notes.append(data[1])

# %% [markdown]
# #### Apply min-max scalling

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(np.array(notes).reshape(-1, 1))
notes = list(scaler.transform(np.array(notes).reshape(-1, 1)))

# %% [markdown]
# #### Prepare features for training and data subsample for prediction

# %%
# LSTM layers requires that data must have a certain shape
# create list of lists fist
notes = [list(note) for note in notes]

# subsample data for training and prediction
X = []
y = []
# number of notes in a batch
n_prev = 30
for i in range(len(notes) - n_prev):
    X.append(notes[i : i + n_prev])
    y.append(notes[i + n_prev])
# save a seed to do prediction later
X_test = X[-300:]
X = X[:-300]
y = y[:-300]

# %% [markdown]
# #### Made sequential model with several layers, use LSTM as it time dependent data
#
# I also whant to save checkpoints

# %%
model = Sequential()
model.add(LSTM(256, input_shape=(n_prev, 1), return_sequences=True))
model.add(Dropout(0.6))
model.add(LSTM(128, input_shape=(n_prev, 1), return_sequences=True))
model.add(Dropout(0.6))
model.add(LSTM(64, input_shape=(n_prev, 1), return_sequences=False))
model.add(Dropout(0.6))
model.add(Dense(1))
model.add(Activation("linear"))
optimizer = Adam(learning_rate=0.001)
model.compile(loss="mse", optimizer=optimizer)
filepath = "/content/Keras_music_gereration/Checkpoints/checkpoint_model_{epoch:02d}.hdf5"
model_save_callback = ModelCheckpoint(
    filepath,
    monitor="val_acc",
    verbose=1,
    save_best_only=False,
    mode="auto",
    save_freq=5,
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %% [markdown]
# #### Train your model.
# It might take a while

# %%
model.fit(np.array(X), np.array(y), 32, 10, verbose=1, callbacks=[model_save_callback])
# Out:
# Streaming output truncated to the last 5000 lines.
#  9600/12770 [=====================>........] - ETA: 18s - loss: 0.0414
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9632/12770 [=====================>........] - ETA: 17s - loss: 0.0414
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9664/12770 [=====================>........] - ETA: 17s - loss: 0.0414
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9696/12770 [=====================>........] - ETA: 17s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9728/12770 [=====================>........] - ETA: 17s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9760/12770 [=====================>........] - ETA: 17s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9792/12770 [======================>.......] - ETA: 17s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9824/12770 [======================>.......] - ETA: 16s - loss: 0.0414
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9856/12770 [======================>.......] - ETA: 16s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9888/12770 [======================>.......] - ETA: 16s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9920/12770 [======================>.......] - ETA: 16s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9952/12770 [======================>.......] - ETA: 16s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
#  9984/12770 [======================>.......] - ETA: 15s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10016/12770 [======================>.......] - ETA: 15s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10048/12770 [======================>.......] - ETA: 15s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10080/12770 [======================>.......] - ETA: 15s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10112/12770 [======================>.......] - ETA: 15s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10144/12770 [======================>.......] - ETA: 14s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10176/12770 [======================>.......] - ETA: 14s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10208/12770 [======================>.......] - ETA: 14s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10240/12770 [=======================>......] - ETA: 14s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10272/12770 [=======================>......] - ETA: 14s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10304/12770 [=======================>......] - ETA: 14s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10336/12770 [=======================>......] - ETA: 13s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10368/12770 [=======================>......] - ETA: 13s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10400/12770 [=======================>......] - ETA: 13s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10432/12770 [=======================>......] - ETA: 13s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10464/12770 [=======================>......] - ETA: 13s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10496/12770 [=======================>......] - ETA: 12s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10528/12770 [=======================>......] - ETA: 12s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10560/12770 [=======================>......] - ETA: 12s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10592/12770 [=======================>......] - ETA: 12s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10624/12770 [=======================>......] - ETA: 12s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10656/12770 [========================>.....] - ETA: 12s - loss: 0.0413
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10688/12770 [========================>.....] - ETA: 11s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10720/12770 [========================>.....] - ETA: 11s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10752/12770 [========================>.....] - ETA: 11s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10784/12770 [========================>.....] - ETA: 11s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10816/12770 [========================>.....] - ETA: 11s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10848/12770 [========================>.....] - ETA: 10s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10880/12770 [========================>.....] - ETA: 10s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10912/12770 [========================>.....] - ETA: 10s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10944/12770 [========================>.....] - ETA: 10s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 10976/12770 [========================>.....] - ETA: 10s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11008/12770 [========================>.....] - ETA: 10s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11040/12770 [========================>.....] - ETA: 9s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11072/12770 [=========================>....] - ETA: 9s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11104/12770 [=========================>....] - ETA: 9s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11136/12770 [=========================>....] - ETA: 9s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11168/12770 [=========================>....] - ETA: 9s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11200/12770 [=========================>....] - ETA: 8s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11232/12770 [=========================>....] - ETA: 8s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11264/12770 [=========================>....] - ETA: 8s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11296/12770 [=========================>....] - ETA: 8s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11328/12770 [=========================>....] - ETA: 8s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11360/12770 [=========================>....] - ETA: 8s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11392/12770 [=========================>....] - ETA: 7s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11424/12770 [=========================>....] - ETA: 7s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11456/12770 [=========================>....] - ETA: 7s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11488/12770 [=========================>....] - ETA: 7s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11520/12770 [==========================>...] - ETA: 7s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11552/12770 [==========================>...] - ETA: 6s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11584/12770 [==========================>...] - ETA: 6s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11616/12770 [==========================>...] - ETA: 6s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11648/12770 [==========================>...] - ETA: 6s - loss: 0.0412
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11680/12770 [==========================>...] - ETA: 6s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11712/12770 [==========================>...] - ETA: 6s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11744/12770 [==========================>...] - ETA: 5s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11776/12770 [==========================>...] - ETA: 5s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11808/12770 [==========================>...] - ETA: 5s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11840/12770 [==========================>...] - ETA: 5s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11872/12770 [==========================>...] - ETA: 5s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11904/12770 [==========================>...] - ETA: 4s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11936/12770 [===========================>..] - ETA: 4s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 11968/12770 [===========================>..] - ETA: 4s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12000/12770 [===========================>..] - ETA: 4s - loss: 0.0411
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12032/12770 [===========================>..] - ETA: 4s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12064/12770 [===========================>..] - ETA: 4s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12096/12770 [===========================>..] - ETA: 3s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12128/12770 [===========================>..] - ETA: 3s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12160/12770 [===========================>..] - ETA: 3s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12192/12770 [===========================>..] - ETA: 3s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12224/12770 [===========================>..] - ETA: 3s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12256/12770 [===========================>..] - ETA: 2s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12288/12770 [===========================>..] - ETA: 2s - loss: 0.0409
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12320/12770 [===========================>..] - ETA: 2s - loss: 0.0409
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12352/12770 [============================>.] - ETA: 2s - loss: 0.0409
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12384/12770 [============================>.] - ETA: 2s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12416/12770 [============================>.] - ETA: 2s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12448/12770 [============================>.] - ETA: 1s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12480/12770 [============================>.] - ETA: 1s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12512/12770 [============================>.] - ETA: 1s - loss: 0.0410
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12544/12770 [============================>.] - ETA: 1s - loss: 0.0409
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12576/12770 [============================>.] - ETA: 1s - loss: 0.0409
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12608/12770 [============================>.] - ETA: 0s - loss: 0.0409
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12640/12770 [============================>.] - ETA: 0s - loss: 0.0409
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12672/12770 [============================>.] - ETA: 0s - loss: 0.0408
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12704/12770 [============================>.] - ETA: 0s - loss: 0.0408
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12736/12770 [============================>.] - ETA: 0s - loss: 0.0408
# Epoch 00004: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_04.hdf5
# 12770/12770 [==============================] - 73s 6ms/sample - loss: 0.0408
# Epoch 5/10
#
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#    32/12770 [..............................] - ETA: 1:09 - loss: 0.0511
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#    64/12770 [..............................] - ETA: 1:11 - loss: 0.0473
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#    96/12770 [..............................] - ETA: 1:12 - loss: 0.0404
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   128/12770 [..............................] - ETA: 1:10 - loss: 0.0377
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   160/12770 [..............................] - ETA: 1:10 - loss: 0.0377
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   192/12770 [..............................] - ETA: 1:10 - loss: 0.0397
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   224/12770 [..............................] - ETA: 1:09 - loss: 0.0376
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   256/12770 [..............................] - ETA: 1:09 - loss: 0.0373
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   288/12770 [..............................] - ETA: 1:09 - loss: 0.0364
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   320/12770 [..............................] - ETA: 1:09 - loss: 0.0385
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   352/12770 [..............................] - ETA: 1:14 - loss: 0.0371
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   384/12770 [..............................] - ETA: 1:14 - loss: 0.0389
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   416/12770 [..............................] - ETA: 1:13 - loss: 0.0391
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   448/12770 [>.............................] - ETA: 1:13 - loss: 0.0395
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   480/12770 [>.............................] - ETA: 1:12 - loss: 0.0393
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   512/12770 [>.............................] - ETA: 1:12 - loss: 0.0390
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   544/12770 [>.............................] - ETA: 1:11 - loss: 0.0394
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   576/12770 [>.............................] - ETA: 1:10 - loss: 0.0392
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   608/12770 [>.............................] - ETA: 1:10 - loss: 0.0390
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   640/12770 [>.............................] - ETA: 1:10 - loss: 0.0385
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   672/12770 [>.............................] - ETA: 1:10 - loss: 0.0387
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   704/12770 [>.............................] - ETA: 1:09 - loss: 0.0394
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   736/12770 [>.............................] - ETA: 1:09 - loss: 0.0394
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   768/12770 [>.............................] - ETA: 1:09 - loss: 0.0391
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   800/12770 [>.............................] - ETA: 1:08 - loss: 0.0392
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   832/12770 [>.............................] - ETA: 1:08 - loss: 0.0391
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   864/12770 [=>............................] - ETA: 1:08 - loss: 0.0389
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   896/12770 [=>............................] - ETA: 1:08 - loss: 0.0388
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   928/12770 [=>............................] - ETA: 1:07 - loss: 0.0385
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   960/12770 [=>............................] - ETA: 1:07 - loss: 0.0385
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#   992/12770 [=>............................] - ETA: 1:07 - loss: 0.0387
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1024/12770 [=>............................] - ETA: 1:07 - loss: 0.0385
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1056/12770 [=>............................] - ETA: 1:07 - loss: 0.0381
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1088/12770 [=>............................] - ETA: 1:06 - loss: 0.0381
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1120/12770 [=>............................] - ETA: 1:06 - loss: 0.0379
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1152/12770 [=>............................] - ETA: 1:06 - loss: 0.0378
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1184/12770 [=>............................] - ETA: 1:06 - loss: 0.0376
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1216/12770 [=>............................] - ETA: 1:10 - loss: 0.0373
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1248/12770 [=>............................] - ETA: 1:09 - loss: 0.0375
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1280/12770 [==>...........................] - ETA: 1:09 - loss: 0.0377
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1312/12770 [==>...........................] - ETA: 1:09 - loss: 0.0375
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1344/12770 [==>...........................] - ETA: 1:08 - loss: 0.0373
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1376/12770 [==>...........................] - ETA: 1:08 - loss: 0.0374
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1408/12770 [==>...........................] - ETA: 1:08 - loss: 0.0375
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1440/12770 [==>...........................] - ETA: 1:07 - loss: 0.0377
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1472/12770 [==>...........................] - ETA: 1:07 - loss: 0.0376
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1504/12770 [==>...........................] - ETA: 1:07 - loss: 0.0375
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1536/12770 [==>...........................] - ETA: 1:06 - loss: 0.0372
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1568/12770 [==>...........................] - ETA: 1:06 - loss: 0.0374
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1600/12770 [==>...........................] - ETA: 1:06 - loss: 0.0376
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1632/12770 [==>...........................] - ETA: 1:06 - loss: 0.0375
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1664/12770 [==>...........................] - ETA: 1:05 - loss: 0.0378
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1696/12770 [==>...........................] - ETA: 1:05 - loss: 0.0376
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1728/12770 [===>..........................] - ETA: 1:05 - loss: 0.0377
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1760/12770 [===>..........................] - ETA: 1:05 - loss: 0.0378
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1792/12770 [===>..........................] - ETA: 1:04 - loss: 0.0376
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1824/12770 [===>..........................] - ETA: 1:04 - loss: 0.0376
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1856/12770 [===>..........................] - ETA: 1:04 - loss: 0.0374
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1888/12770 [===>..........................] - ETA: 1:04 - loss: 0.0372
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1920/12770 [===>..........................] - ETA: 1:03 - loss: 0.0372
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1952/12770 [===>..........................] - ETA: 1:03 - loss: 0.0372
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  1984/12770 [===>..........................] - ETA: 1:03 - loss: 0.0373
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2016/12770 [===>..........................] - ETA: 1:03 - loss: 0.0373
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2048/12770 [===>..........................] - ETA: 1:05 - loss: 0.0372
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2080/12770 [===>..........................] - ETA: 1:05 - loss: 0.0372
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2112/12770 [===>..........................] - ETA: 1:04 - loss: 0.0373
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2144/12770 [====>.........................] - ETA: 1:04 - loss: 0.0372
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2176/12770 [====>.........................] - ETA: 1:04 - loss: 0.0371
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2208/12770 [====>.........................] - ETA: 1:04 - loss: 0.0369
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2240/12770 [====>.........................] - ETA: 1:03 - loss: 0.0368
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2272/12770 [====>.........................] - ETA: 1:03 - loss: 0.0368
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2304/12770 [====>.........................] - ETA: 1:03 - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2336/12770 [====>.........................] - ETA: 1:03 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2368/12770 [====>.........................] - ETA: 1:02 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2400/12770 [====>.........................] - ETA: 1:02 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2432/12770 [====>.........................] - ETA: 1:02 - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2464/12770 [====>.........................] - ETA: 1:02 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2496/12770 [====>.........................] - ETA: 1:01 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2528/12770 [====>.........................] - ETA: 1:01 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2560/12770 [=====>........................] - ETA: 1:01 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2592/12770 [=====>........................] - ETA: 1:01 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2624/12770 [=====>........................] - ETA: 1:00 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2656/12770 [=====>........................] - ETA: 1:00 - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2688/12770 [=====>........................] - ETA: 1:00 - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2720/12770 [=====>........................] - ETA: 1:00 - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2752/12770 [=====>........................] - ETA: 59s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2784/12770 [=====>........................] - ETA: 59s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2816/12770 [=====>........................] - ETA: 59s - loss: 0.0368
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2848/12770 [=====>........................] - ETA: 59s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2880/12770 [=====>........................] - ETA: 59s - loss: 0.0368
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2912/12770 [=====>........................] - ETA: 59s - loss: 0.0369
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2944/12770 [=====>........................] - ETA: 59s - loss: 0.0370
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  2976/12770 [=====>........................] - ETA: 59s - loss: 0.0369
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3008/12770 [======>.......................] - ETA: 58s - loss: 0.0371
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3040/12770 [======>.......................] - ETA: 58s - loss: 0.0371
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3072/12770 [======>.......................] - ETA: 58s - loss: 0.0371
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3104/12770 [======>.......................] - ETA: 58s - loss: 0.0370
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3136/12770 [======>.......................] - ETA: 57s - loss: 0.0368
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3168/12770 [======>.......................] - ETA: 57s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3200/12770 [======>.......................] - ETA: 57s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3232/12770 [======>.......................] - ETA: 57s - loss: 0.0368
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3264/12770 [======>.......................] - ETA: 57s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3296/12770 [======>.......................] - ETA: 56s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3328/12770 [======>.......................] - ETA: 56s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3360/12770 [======>.......................] - ETA: 56s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3392/12770 [======>.......................] - ETA: 56s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3424/12770 [=======>......................] - ETA: 56s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3456/12770 [=======>......................] - ETA: 55s - loss: 0.0364
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3488/12770 [=======>......................] - ETA: 55s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3520/12770 [=======>......................] - ETA: 55s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3552/12770 [=======>......................] - ETA: 55s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3584/12770 [=======>......................] - ETA: 54s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3616/12770 [=======>......................] - ETA: 54s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3648/12770 [=======>......................] - ETA: 54s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3680/12770 [=======>......................] - ETA: 54s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3712/12770 [=======>......................] - ETA: 54s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3744/12770 [=======>......................] - ETA: 53s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3776/12770 [=======>......................] - ETA: 53s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3808/12770 [=======>......................] - ETA: 53s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3840/12770 [========>.....................] - ETA: 53s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3872/12770 [========>.....................] - ETA: 53s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3904/12770 [========>.....................] - ETA: 52s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3936/12770 [========>.....................] - ETA: 52s - loss: 0.0368
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  3968/12770 [========>.....................] - ETA: 52s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4000/12770 [========>.....................] - ETA: 52s - loss: 0.0367
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4032/12770 [========>.....................] - ETA: 51s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4064/12770 [========>.....................] - ETA: 51s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4096/12770 [========>.....................] - ETA: 51s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4128/12770 [========>.....................] - ETA: 51s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4160/12770 [========>.....................] - ETA: 51s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4192/12770 [========>.....................] - ETA: 50s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4224/12770 [========>.....................] - ETA: 50s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4256/12770 [========>.....................] - ETA: 50s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4288/12770 [=========>....................] - ETA: 50s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4320/12770 [=========>....................] - ETA: 50s - loss: 0.0364
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4352/12770 [=========>....................] - ETA: 49s - loss: 0.0364
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4384/12770 [=========>....................] - ETA: 49s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4416/12770 [=========>....................] - ETA: 49s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4448/12770 [=========>....................] - ETA: 49s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4480/12770 [=========>....................] - ETA: 49s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4512/12770 [=========>....................] - ETA: 48s - loss: 0.0366
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4544/12770 [=========>....................] - ETA: 48s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4576/12770 [=========>....................] - ETA: 49s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4608/12770 [=========>....................] - ETA: 49s - loss: 0.0365
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4640/12770 [=========>....................] - ETA: 48s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4672/12770 [=========>....................] - ETA: 48s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4704/12770 [==========>...................] - ETA: 48s - loss: 0.0363
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4736/12770 [==========>...................] - ETA: 48s - loss: 0.0362
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4768/12770 [==========>...................] - ETA: 48s - loss: 0.0362
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4800/12770 [==========>...................] - ETA: 47s - loss: 0.0362
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4832/12770 [==========>...................] - ETA: 47s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4864/12770 [==========>...................] - ETA: 47s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4896/12770 [==========>...................] - ETA: 47s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4928/12770 [==========>...................] - ETA: 47s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4960/12770 [==========>...................] - ETA: 46s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  4992/12770 [==========>...................] - ETA: 46s - loss: 0.0362
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5024/12770 [==========>...................] - ETA: 46s - loss: 0.0362
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5056/12770 [==========>...................] - ETA: 46s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5088/12770 [==========>...................] - ETA: 46s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5120/12770 [===========>..................] - ETA: 45s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5152/12770 [===========>..................] - ETA: 45s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5184/12770 [===========>..................] - ETA: 45s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5216/12770 [===========>..................] - ETA: 45s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5248/12770 [===========>..................] - ETA: 45s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5280/12770 [===========>..................] - ETA: 44s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5312/12770 [===========>..................] - ETA: 44s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5344/12770 [===========>..................] - ETA: 44s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5376/12770 [===========>..................] - ETA: 44s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5408/12770 [===========>..................] - ETA: 44s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5440/12770 [===========>..................] - ETA: 43s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5472/12770 [===========>..................] - ETA: 43s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5504/12770 [===========>..................] - ETA: 43s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5536/12770 [============>.................] - ETA: 43s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5568/12770 [============>.................] - ETA: 42s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5600/12770 [============>.................] - ETA: 42s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5632/12770 [============>.................] - ETA: 42s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5664/12770 [============>.................] - ETA: 42s - loss: 0.0362
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5696/12770 [============>.................] - ETA: 42s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5728/12770 [============>.................] - ETA: 41s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5760/12770 [============>.................] - ETA: 41s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5792/12770 [============>.................] - ETA: 41s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5824/12770 [============>.................] - ETA: 41s - loss: 0.0361
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5856/12770 [============>.................] - ETA: 41s - loss: 0.0360
# Epoch 00005: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_05.hdf5
#  5888/12770 [============>.................] - ETA: 40s - loss: 0.0360
# ...
#  9760/12770 [=====================>........] - ETA: 18s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
#  9792/12770 [======================>.......] - ETA: 18s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
#  9824/12770 [======================>.......] - ETA: 18s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
#  9856/12770 [======================>.......] - ETA: 17s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
#  9888/12770 [======================>.......] - ETA: 17s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
#  9920/12770 [======================>.......] - ETA: 17s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
#  9952/12770 [======================>.......] - ETA: 17s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
#  9984/12770 [======================>.......] - ETA: 17s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10016/12770 [======================>.......] - ETA: 16s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10048/12770 [======================>.......] - ETA: 16s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10080/12770 [======================>.......] - ETA: 16s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10112/12770 [======================>.......] - ETA: 16s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10144/12770 [======================>.......] - ETA: 16s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10176/12770 [======================>.......] - ETA: 16s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10208/12770 [======================>.......] - ETA: 15s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10240/12770 [=======================>......] - ETA: 15s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10272/12770 [=======================>......] - ETA: 15s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10304/12770 [=======================>......] - ETA: 15s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10336/12770 [=======================>......] - ETA: 15s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10368/12770 [=======================>......] - ETA: 14s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10400/12770 [=======================>......] - ETA: 14s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10432/12770 [=======================>......] - ETA: 14s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10464/12770 [=======================>......] - ETA: 14s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10496/12770 [=======================>......] - ETA: 14s - loss: 0.0161
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10528/12770 [=======================>......] - ETA: 13s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10560/12770 [=======================>......] - ETA: 13s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10592/12770 [=======================>......] - ETA: 13s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10624/12770 [=======================>......] - ETA: 13s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10656/12770 [========================>.....] - ETA: 13s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10688/12770 [========================>.....] - ETA: 12s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10720/12770 [========================>.....] - ETA: 12s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10752/12770 [========================>.....] - ETA: 12s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10784/12770 [========================>.....] - ETA: 12s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10816/12770 [========================>.....] - ETA: 12s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10848/12770 [========================>.....] - ETA: 11s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10880/12770 [========================>.....] - ETA: 11s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10912/12770 [========================>.....] - ETA: 11s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10944/12770 [========================>.....] - ETA: 11s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 10976/12770 [========================>.....] - ETA: 11s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11008/12770 [========================>.....] - ETA: 10s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11040/12770 [========================>.....] - ETA: 10s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11072/12770 [=========================>....] - ETA: 10s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11104/12770 [=========================>....] - ETA: 10s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11136/12770 [=========================>....] - ETA: 10s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11168/12770 [=========================>....] - ETA: 9s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11200/12770 [=========================>....] - ETA: 9s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11232/12770 [=========================>....] - ETA: 9s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11264/12770 [=========================>....] - ETA: 9s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11296/12770 [=========================>....] - ETA: 9s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11328/12770 [=========================>....] - ETA: 8s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11360/12770 [=========================>....] - ETA: 8s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11392/12770 [=========================>....] - ETA: 8s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11424/12770 [=========================>....] - ETA: 8s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11456/12770 [=========================>....] - ETA: 8s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11488/12770 [=========================>....] - ETA: 7s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11520/12770 [==========================>...] - ETA: 7s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11552/12770 [==========================>...] - ETA: 7s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11584/12770 [==========================>...] - ETA: 7s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11616/12770 [==========================>...] - ETA: 7s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11648/12770 [==========================>...] - ETA: 6s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11680/12770 [==========================>...] - ETA: 6s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11712/12770 [==========================>...] - ETA: 6s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11744/12770 [==========================>...] - ETA: 6s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11776/12770 [==========================>...] - ETA: 6s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11808/12770 [==========================>...] - ETA: 5s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11840/12770 [==========================>...] - ETA: 5s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11872/12770 [==========================>...] - ETA: 5s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11904/12770 [==========================>...] - ETA: 5s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11936/12770 [===========================>..] - ETA: 5s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 11968/12770 [===========================>..] - ETA: 4s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12000/12770 [===========================>..] - ETA: 4s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12032/12770 [===========================>..] - ETA: 4s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12064/12770 [===========================>..] - ETA: 4s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12096/12770 [===========================>..] - ETA: 4s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12128/12770 [===========================>..] - ETA: 3s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12160/12770 [===========================>..] - ETA: 3s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12192/12770 [===========================>..] - ETA: 3s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12224/12770 [===========================>..] - ETA: 3s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12256/12770 [===========================>..] - ETA: 3s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12288/12770 [===========================>..] - ETA: 2s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12320/12770 [===========================>..] - ETA: 2s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12352/12770 [============================>.] - ETA: 2s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12384/12770 [============================>.] - ETA: 2s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12416/12770 [============================>.] - ETA: 2s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12448/12770 [============================>.] - ETA: 1s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12480/12770 [============================>.] - ETA: 1s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12512/12770 [============================>.] - ETA: 1s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12544/12770 [============================>.] - ETA: 1s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12576/12770 [============================>.] - ETA: 1s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12608/12770 [============================>.] - ETA: 0s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12640/12770 [============================>.] - ETA: 0s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12672/12770 [============================>.] - ETA: 0s - loss: 0.0160
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12704/12770 [============================>.] - ETA: 0s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12736/12770 [============================>.] - ETA: 0s - loss: 0.0159
# Epoch 00010: saving model to /content/Keras_music_gereration/Checkpoints/checkpoint_model_10.hdf5
# 12770/12770 [==============================] - 79s 6ms/sample - loss: 0.0159

# %% [markdown]
# #### Make a prediction

# %%
prediction = model.predict(np.array(X_test))
prediction = np.squeeze(prediction)
prediction = np.squeeze(scaler.inverse_transform(prediction.reshape(-1, 1)))
prediction = [int(i) for i in prediction]

# %% [markdown]
# #### Save your result to new midi file

# %%
mid = MidiFile()
track = MidiTrack()
t = 0
for note in prediction:
    msg_on = Message.from_dict({'type': 'note_on', 'channel': 0, 'note': note, 'velocity': 67, 'time':0})
    # you need to add some pauses "note_off"
    msg_off = Message.from_dict({'type': 'note_off', 'channel': 0, 'note': note, 'velocity': 67, 'time':64})
    track.append(msg_on)
    track.append(msg_off)
    track.append(msg_off)
mid.tracks.append(track)
mid.save("/content/drive/MyDrive/GAN music/LSTM_music_10_epoch.mid")

# %% [markdown]
# #### Just listen to it. The result is surreal!
